# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from pylab import *

# %%
myfont = matplotlib.font_manager.FontProperties(fname="C:/Windows/Fonts/simfang.ttf")
mpl.rcParams['axes.unicode_minus'] = False
plt.figure(num=1, figsize=(8,7))

xtick=np.linspace(0,6000,11)
ytick=np.linspace(0.3,1,8)
#数据
x=np.linspace(150,6000,40)
print(x)
y=[0.5691,0.7089,0.7633,0.7956,0.7897,0.7868,0.8118,0.8059,0.8279,
   0.8397,0.8191,0.8088,0.8147,0.8412,0.8559,0.8236,0.8456,0.8676,
   0.8765,0.8442,0.8691,0.8794,0.8691,0.8868,0.8765,0.8838,0.8691,
   0.8941,0.9015,0.9118,0.8985,0.9118,0.8779,0.9103,0.8824,0.9103,
   0.9015,0.8985,0.9132,0.9024]

y1=[0.5897,0.6750,0.7353,0.7941,0.7912,0.8133,0.8103,0.8074,0.8088,
    0.8279,0.8383,0.8515,0.8176,0.8118,0.8309,0.8559,0.8677,0.8471,
    0.8573,0.8529,0.8368,0.8765,0.8956,0.8603,0.8824,0.8544,0.8397,
    0.8632,0.8720,0.8779,0.8603,0.9044,0.8809,0.8941,0.8927,0.8691,
    0.8912,0.8794,0.8985,0.9015]
y2=[0.6823,0.5300,0.6421,0.7380,0.8477,0.7386,0.7212,0.7152,0.6571,
    0.7770,0.6037,0.7164,0.7938,0.8022,0.7566,0.7644,0.8363,0.8807,
    0.8741,0.7888,0.8885,0.8835,0.8458,0.8978,0.8140,0.8879,0.8771,
    0.8765,0.8837,0.8262,0.8663,0.8391,0.8579,0.8453,0.8819,0.8999,
    0.8618,0.8873,0.8935,0.8829]

y3=[0.5036,0.5360,0.5522,0.7363,0.7609,0.7050,0.7122,0.7986,0.8159,
    0.8681,0.8225,0.7526,0.8112,0.7992,0.8429,0.8455,0.8165,0.8459,
    0.8607,0.8417,0.8788,0.8563,0.8084,0.8335,0.8575,0.8633,0.8194,
    0.8319,0.8344,0.8485,0.8309,0.8554,0.8153,0.8543,0.8518,0.8610,
    0.8567,0.8647,0.8654,0.8590]

y4=[0.5000,0.4893,0.5655,0.5595,0.5671,0.5854,0.5000,0.5351,0.5655,
    0.5244,0.5503,0.5518,0.5412,0.5747,0.5960,0.5915,0.5976,0.6250,
    0.5960,0.6265,0.6326,0.6433,0.6418,0.6662,0.6555,0.6631,0.6662,
    0.7119,0.6677,0.6814,0.6875,0.6905,0.7149,0.7500,0.7622,0.7607,
    0.7729,0.7866,0.7849,0.7576]

y5=[0.5168,0.5012,0.5000,0.4958,0.4982,0.4597,0.5012,0.5300,0.5012,
    0.4844,0.5234,0.5457,0.5913,0.4718,0.5529,0.5709,0.6124,0.6361,
    0.6550,0.6803,0.6587,0.6548,0.6200,0.5763,0.6704,0.6662,0.6963,
    0.7074,0.6028,0.6509,0.5927,0.6606,0.7113,0.6728,0.7046,0.7398,
    0.6690,0.7218,0.7458,0.6716]

y6=[0.6853,0.7294,0.7618,0.8015,0.8073,0.8103,0.8338,0.8397,0.8250,
    0.8456,0.8088,0.8676,0.8750,0.8133,0.8529,0.8412,0.8735,0.8735,
    0.8676,0.8721,0.8250,0.8632,0.8823,0.8750,0.8559,0.8765,0.8618,
    0.8691,0.8715,0.8735,0.8676,0.8691,0.8771,0.8885,0.8826,0.8841,
    0.8721,0.8985, 0.8838,0.8812]

y7=[0.5474,0.7810,0.7662,0.7867,0.7025,0.6330,0.7639,0.7760,0.8627,
    0.8363,0.8609,0.7739,0.8519,0.7410,0.7272,0.8285,0.7962,0.8501,
    0.8367,0.7998,0.8615,0.8639,0.8537,0.8036,0.8106,0.8159,0.8633,
    0.8189,0.8288,0.8462,0.8229,0.8147,0.8477,0.8447,0.8553,0.8489,
    0.8421,0.8715,0.8654,0.8665]


#mfc='w'
plt.plot(x,y6,color='black', marker='s', linestyle='-',
        linewidth=1, markersize=4,label='inceptionv3/Train data')

plt.plot(x,y7,color='black', marker='s', linestyle='-',mfc='w',
        linewidth=1, markersize=4,label='inceptionv3/Test data')

plt.plot(x,y,color='green', marker='^', linestyle='-',
        linewidth=1, markersize=5,label='inceptionv3+1FCL/Train data')

plt.plot(x,y2,color='green', marker='^',linestyle='-',mfc='w',
        linewidth=1, markersize=5,label='inceptionv3+1FCL/Test data')

plt.plot(x,y1,color='blue', marker='o',linestyle='-',
        linewidth=1, markersize=5,label='inceptionv3+2FCL/Train data')

plt.plot(x,y3,color='blue', marker='o',linestyle='-',mfc='w',
        linewidth=1, markersize=5,label='inceptionv3+2FCL/Test data')

plt.plot(x,y4,color='red', marker='*',linestyle='-',
        linewidth=1, markersize=5,label='Non-transfer learning/Train data')

plt.plot(x,y5,color='red', marker='*',linestyle='-',mfc='w',
        linewidth=1, markersize=5,label='Non-transfer learning/Test data')

plt.xlabel("Iteration",fontsize=12) 
plt.ylabel("Accuracy",fontsize=12)
plt.xticks(xtick)
plt.yticks(ytick)
plt.xlim(0,6500)

plt.legend(loc=4,fontsize="small") 
plt.savefig("inception result.png")
plt.show()
# Out:
# [ 150.  300.  450.  600.  750.  900. 1050. 1200. 1350. 1500. 1650. 1800.
#  1950. 2100. 2250. 2400. 2550. 2700. 2850. 3000. 3150. 3300. 3450. 3600.
#  3750. 3900. 4050. 4200. 4350. 4500. 4650. 4800. 4950. 5100. 5250. 5400.
#  5550. 5700. 5850. 6000.]
